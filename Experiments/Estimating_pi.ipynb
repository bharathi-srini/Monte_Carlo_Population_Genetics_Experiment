# %%
import math
import random

import matplotlib
matplotlib.use('TkAgg')
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# /Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-729fa3a81151>", line 3, in <module>
#     import matplotlib.pyplot as plt
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/matplotlib/pyplot.py", line 69, in <module>
#     from matplotlib.backends import pylab_setup
#   File "/Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   """

# %%
def estimate_pi(samples):  
    hits = 0
    for _ in range(samples):
        x = random.random()
        y = random.random()
        if math.sqrt((x ** 2) + (y ** 2)) < 1:
            hits += 1
    ratio = (float(hits) / samples) * 4
    print('Estimate with {0} samples: {1}'.format(samples, ratio))

# %%
estimate_pi(samples=10)  
estimate_pi(samples=100)  
estimate_pi(samples=1000)  
estimate_pi(samples=10000)  
estimate_pi(samples=100000)  
estimate_pi(samples=1000000)
# Out:
# Estimate with 10 samples: 4.0
# Estimate with 100 samples: 3.16
# Estimate with 1000 samples: 3.156
# Estimate with 10000 samples: 3.1512
# Estimate with 100000 samples: 3.14404
# Estimate with 1000000 samples: 3.141388

# %%
def plot_pi_estimate(samples):  
    hits = 0
    x_inside = []
    y_inside = []
    x_outside = []
    y_outside = []
    for _ in range(samples):
        x = random.random()
        y = random.random()
        if math.sqrt((x ** 2) + (y ** 2)) < 1:
            hits += 1
            x_inside.append(x)
            y_inside.append(y)
        else:
            x_outside.append(x)
            y_outside.append(y)
    fig, ax = plt.subplots(figsize=(12, 9))
    ax.set_aspect('equal')
    ax.scatter(x_inside, y_inside, s=20, c='b')
    ax.scatter(x_outside, y_outside, s=20, c='r')
    fig.show()
    ratio = (float(hits) / samples) * 4
    print('Estimate with {0} samples: {1}'.format(samples, ratio))

# %%
plot_pi_estimate(samples=10000)
# Out:
# Estimate with 10000 samples: 3.1412
# /Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
plot_pi_estimate(samples=100000)
# Out:
# /Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# Estimate with 100000 samples: 3.13936
